# %%
import matplotlib.pyplot as plt #imports library
import numpy as np
import csv

# %%
from google.colab import drive #mounts drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
csvFile = open("/content/drive/MyDrive/Colab Notebooks/chlorophyll_mgm3_Dec_2002.csv", 'r') #reads file
csvReader = csv.reader(csvFile, delimiter=',')
data_lists = list(csvReader)

# %%
#Number of rows is the height
height = len(data_lists)

#Number of items in each row (aka columns) is the width
width = len(data_lists[0])

grid = np.empty([height, width, 3], dtype=np.uint8)

# %%
#finds the minimum and the maximum
print(min(all_values))
print(max(all_values))
# Out:
# 0.0111
# 69.2596

# %%
all_values = [] # We will fill in this empty list with all the data values as we go

#Storing color values in "grid"

for r, row in enumerate(data_lists): #For loop keeping track of row indexes (r) and row lists (row)
    for c, value in enumerate(row): #For loop keeping track of each individual row value's index and each value within an individual row
        if float(value) < 99999:
            all_values.append(float(value)) # This is where we fill in the list with all data values
        if float(value) <= 0.0111: #Checking the concentration of plankton
            grid[r, c] = [0, 0, 255] #Applying the color to the grid based on the concentration of plankton
        elif float(value) <= 0.02:
            grid[r, c] = [0, 0, 180]
        elif float(value) <= 0.03:
            grid[r, c] = [0, 0, 150]
        elif float(value) <= 0.04:
            grid[r, c] = [0, 0, 120]
        elif float(value) <= 0.05:
            grid[r, c] = [0, 0, 100]
        elif float(value) <= 0.1:
            grid[r, c] = [0, 128, 255]
        elif float(value) <= 0.2:
            grid[r, c] = [0, 255, 255]
        elif float(value) <= 0.3:
            grid[r, c] = [0, 255, 128]
        elif float(value) <= 0.4:
            grid[r, c] = [0, 255, 0]
        elif float(value) <= 0.5:
            grid[r, c] = [128, 255, 0]
        elif float(value) <= 0.6:
            grid[r, c] = [153, 255, 51]
        elif float(value) <= 0.7:
            grid[r, c] = [255, 255, 0]
        elif float(value) <= 0.8:
            grid[r, c] = [255, 153, 51]
        elif float(value) <= 0.9:
            grid[r, c] = [255, 128, 0]
        elif float(value) <= 1:
            grid[r, c] = [255, 0, 0]
        elif float(value) <= 2:
            grid[r, c] = [204, 0, 0]
        elif float(value) <= 35:
            grid[r, c] = [180, 0, 0]
        elif float(value) <= 69.2596:
            grid[r, c] = [255, 0, 0]
        else:
            grid[r, c] = [0, 0, 0]

print(all_values)
# Out:
# [0.2804, 0.3115, 0.2804, 0.2804, 0.2524, 0.2353, 0.2524, 0.2353, 0.2045, 0.3846, 0.4425, 0.5859, 0.8619, 0.5657, 0.5462, 0.3585, 0.2437, 0.2524, 0.3227, 0.3227, 0.2524, 0.2524, 0.2707, 0.2707, 0.4272, 0.2437, 0.2437, 0.2045, 0.1906, 0.2193, 0.2353, 0.2045, 0.2193, 0.2118, 0.1906, 0.3008, 0.4747, 0.4272, 0.5657, 0.5462, 0.4583, 1.932, 1.679, 0.3983, 0.2193, 0.184, 0.1491, 0.144, 0.139, 0.5657, 0.5092, 0.3983, 0.4583, 0.4125, 0.2614, 0.1906, 0.2904, 0.3008, 0.3342, 0.1974, 0.2707, 0.3008, 0.2437, 0.1716, 0.184, 0.2804, 0.2904, 0.3008, 0.2437, 0.3008, 0.3713, 0.3227, 0.3983, 0.3846, 0.4125, 0.2904, 0.2614, 0.2707, 0.2707, 0.2118, 0.2707, 0.1777, 0.2353, 0.2524, 0.2118, 0.2437, 0.2353, 0.2193, 0.2353, 0.1974, 0.2045, 0.4747, 0.3461, 0.2118, 0.2524, 0.1657, 0.4425, 0.5859, 0.5274, 0.4425, 0.3227, 0.4125, 4.8111, 3.0487, 1.7389, 0.4747, 0.651, 0.5462, 0.7491, 0.651, 0.6285, 0.5092, 0.5462, 0.6983, 0.3115, 0.3461, 0.8619, 1.2243, 1.5112, 0.9246, 0.4425, 0.3983, 0.3342, 0.3342, 0.3461, 0.197
# ...

# %%
#Makes the actual visual and displays it
plt.title("Chlorophyll & Phytoplankton Concentration Dec 2002")
plt.imshow(grid)
plt.axis('off')
plt.savefig("Chlorophyll_Phytoplankton_2002.png",dpi = 1000)
plt.show()

# %%
#START OF NEXT DATA SET
csvFile2 = open("/content/drive/MyDrive/Colab Notebooks/chlorophyll_mgm3_Dec_2018.csv", 'r') 
csvReader2 = csv.reader(csvFile2, delimiter=',')
data_lists2 = list(csvReader2)

# %%
#Number of rows is the height
height2 = len(data_lists2)

#Number of items in each row (aka columns) is the width
width2 = len(data_lists2[0])

grid2 = np.empty([height2, width2, 3], dtype=np.uint8)

# %%
print(min(all_values2))
print(max(all_values2))
# Out:
# 0.01
# 52.307

# %%
all_values2 = [] # We will fill in this empty list with all the data values as we go

#Storing color values in "grid"

for r, row in enumerate(data_lists2): #For loop keeping track of row indexes (r) and row lists (row)
    for c, value in enumerate(row): #For loop keeping track of each individual row value's index and each value within an individual row
        if float(value) < 99999:
            all_values2.append(float(value)) # This is where we fill in the list with all data values
        if float(value) <= 0.0111: #Checking the temperature
            grid2[r, c] = [0, 0, 255] #Applying the color to the grid based on the temperature
        elif float(value) <= 0.02:
            grid2[r, c] = [0, 0, 180]
        elif float(value) <= 0.03:
            grid2[r, c] = [0, 0, 150]
        elif float(value) <= 0.04:
            grid2[r, c] = [0, 0, 120]
        elif float(value) <= 0.05:
            grid2[r, c] = [0, 0, 100]
        elif float(value) <= 0.1:
            grid2[r, c] = [0, 128, 255]
        elif float(value) <= 0.2:
            grid2[r, c] = [0, 255, 255]
        elif float(value) <= 0.3:
            grid2[r, c] = [0, 255, 128]
        elif float(value) <= 0.4:
            grid2[r, c] = [0, 255, 0]
        elif float(value) <= 0.5:
            grid2[r, c] = [128, 255, 0]
        elif float(value) <= 0.6:
            grid2[r, c] = [153, 255, 51]
        elif float(value) <= 0.7:
            grid2[r, c] = [255, 255, 0]
        elif float(value) <= 0.8:
            grid2[r, c] = [255, 153, 51]
        elif float(value) <= 0.9:
            grid2[r, c] = [255, 128, 0]
        elif float(value) <= 1:
            grid2[r, c] = [255, 0, 0]
        elif float(value) <= 2:
            grid2[r, c] = [204, 0, 0]
        elif float(value) <= 35:
            grid2[r, c] = [180, 0, 0]
        elif float(value) <= 69.2596:
            grid2[r, c] = [255, 0, 0]
        else:
            grid2[r, c] = [0, 0, 0]

print(all_values2)
# Out:
# [0.4747, 0.4425, 0.4425, 0.6068, 0.4916, 0.5092, 0.3461, 0.8619, 0.6068, 0.4916, 1.5112, 1.3602, 0.9918, 1.2243, 1.5652, 1.7389, 1.3133, 2.3025, 1.3133, 0.3713, 0.3008, 0.4125, 0.3227, 0.2707, 0.3342, 0.3461, 0.3008, 0.2193, 0.4125, 0.4425, 0.2045, 0.3461, 0.5462, 0.2804, 0.4272, 0.3227, 0.3585, 0.3846, 2.3025, 1.4088, 1.3602, 1.5652, 5.1608, 1.1019, 3.8976, 1.5112, 0.8927, 0.8035, 0.4747, 0.3846, 0.3713, 0.4425, 0.4747, 0.5274, 0.7232, 0.7758, 0.5859, 0.7232, 1.5652, 0.5274, 0.4425, 0.2437, 1.3133, 0.8035, 0.8619, 0.2614, 0.3115, 0.4747, 0.6742, 0.5092, 0.5274, 0.5274, 0.4747, 0.4272, 0.3846, 0.3115, 0.3461, 0.5462, 0.3342, 0.3115, 0.2437, 0.3461, 0.5092, 0.4583, 0.3585, 0.6983, 0.4583, 0.4583, 0.3585, 0.5657, 0.3713, 0.4272, 0.3846, 0.3983, 0.4125, 0.3342, 0.3115, 0.2353, 0.3227, 0.3008, 0.4916, 0.7232, 0.6068, 1.2243, 1.3133, 1.7389, 3.1576, 4.0368, 3.7632, 3.2704, 3.0487, 2.2231, 0.651, 1.1019, 1.0273, 0.3713, 0.3713, 0.4583, 0.5092, 0.6068, 0.4916, 0.7232, 0.6983, 0.5859, 0.5274
# ...

# %%
plt.title("Chlorophyll & Phytoplankton Concentration Dec 2018")
plt.imshow(grid2)
plt.axis('off')
plt.savefig("Chlorophyll_Phytoplankton_2018.png",dpi = 1000)
#plt.legend[]
plt.show()
